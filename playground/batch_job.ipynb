# %%
from openai import OpenAI
import os
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY_TP"))

batch = client.batches.retrieve("batch_699ca289c8b481908bb105ae2d013221")
print(batch.status)
print(batch)
# Out:
# in_progress
# Batch(id='batch_699ca289c8b481908bb105ae2d013221', completion_window='24h', created_at=1771872905, endpoint='/v1/chat/completions', input_file_id='file-MAjoAiP4vJ76F94AJvHLXp', object='batch', status='in_progress', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1771959305, failed_at=None, finalizing_at=None, in_progress_at=1771872967, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=35), model='gpt-4o-mini-2024-07-18', usage={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens_details': {'reasoning_tokens': 0}})
