# %%
import google.generativeai as genai
import os
genai.configure(api_key='AIzaSyAOBJ9LPDcr3vh0vMgNY7kn0IRA6Y5ws3E')
model = genai.GenerativeModel(model_name="gemini-1.5-flash")
response = model.generate_content("Explain how AI works")
print (response.text)
# Out:
# Artificial intelligence (AI) is a broad field encompassing many techniques, but at its core, AI aims to create systems that can perform tasks that typically require human intelligence.  These tasks include things like learning, reasoning, problem-solving, perception, and natural language understanding.  Here's a breakdown of how different AI approaches work:
#
# **1. Machine Learning (ML):** This is the most prevalent approach to AI today. Instead of being explicitly programmed, ML systems learn from data.  They identify patterns and relationships within the data to make predictions or decisions.  There are several key types of ML:
#
# * **Supervised Learning:** The algorithm is trained on a labeled dataset, meaning the data includes both the input and the desired output.  The algorithm learns to map inputs to outputs. Examples include image classification (input: image; output: label like "cat" or "dog") and spam detection.
# * **Unsupervised Learning:** The algorithm is trained on an unlabeled dataset, meaning it only receives input data without any corresponding output. The algorithm tries to find structure and patterns in the data on its own.  Examples include clustering (grouping similar data points together) and dimensionality reduction (reducing the number of variables while preserving important information).
# * **Reinforcement Learning:** The algorithm learns through trial and error by interacting with an environment. It receives rewards for desirable actions and penalties for undesirable actions.  The goal is to learn a policy that maximizes cumulative rewards.  Examples include game playing (e.g., AlphaGo) and robotics.
#
# **2. Deep Learning (DL):** A subfield of ML that uses artificial neural networks with multiple layers (hence "deep"). These networks are inspired by the structure and function of the human brain.  Deep learning excels at tasks involving complex patterns and high-dimensional data, such as image recognition, natural language processing, and speech recognition.  Different types of neural networks exist, including:
#
# * **Convolutional Neural Networks (CNNs):** Particularly effective for processing image and video data.
# * **Recurrent Neural Networks (RNNs):** Designed for sequential data like text and time series.
# * **Generative Adversarial Networks (GANs):** Used to generate new data samples that resemble the training data.
#
# **3. Expert Systems:**  These AI systems are based on a knowledge base of rules and facts provided by human experts. They use inference engines to reason and make decisions based on the knowledge base.  They are less prevalent now, overshadowed by ML and DL, but still find niche applications.
#
# **4. Natural Language Processing (NLP):** This focuses on enabling computers to understand, interpret, and generate human language.  NLP techniques are used in chatbots, machine translation, sentiment analysis, and text summarization.
#
# **5. Computer Vision:** This field enables computers to "see" and interpret images and videos.  It uses techniques like image recognition, object detection, and image segmentation.
#
#
# **How it works in simple terms:**  AI systems learn from data, identify patterns, and then use those patterns to make predictions or decisions on new, unseen data.  The complexity of this process varies depending on the specific AI technique used, but the core idea remains the same: learning from data to automate tasks.
#
# It's important to note that AI is not a monolithic entity.  Different approaches are better suited for different tasks, and the field is constantly evolving with new techniques and breakthroughs.
